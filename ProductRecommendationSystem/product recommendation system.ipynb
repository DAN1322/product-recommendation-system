# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

import os
from scipy.sparse import coo_matrix

# %%
data = pd.read_csv('marketing_sample_for_walmart_com-walmart_com_product_review__20200701_20201231__5k_data.tsv', sep='\t')

# %%
data
# Out:
#                                Uniq Id            Crawl Timestamp  \
# 0     1705736792d82aa2f2d3caf1c07c53f4  2020-09-24 03:21:12 +0000
# 1     95a9fe6f4810fcfc7ff244fd06784f11  2020-10-30 14:04:08 +0000
# 2     8d4d0330178d3ed181b15a4102b287f2  2020-08-06 05:51:47 +0000
# 3     fddc4df45b35efd886794b261f730c51  2020-07-15 11:22:04 +0000
# 4     0990cf89a59ca6a0460349a3e4f51d42  2020-11-26T12:27:20+00:00
# ...                                ...                        ...
# 4995  2771f0606e9638de508741f52029d51c  2020-07-21 19:00:03 +0000
# 4996  0f218eb3ac736975ccfdde987baa4b83  2020-07-01 05:45:18 +0000
# 4997  34d1aa70845416c3df059a088aaf18dc  2020-12-01T02:02:32+00:00
# 4998  ff9cfa22550bf036e2487a9100d927f1  2020-10-20 21:29:05 +0000
# 4999  0de862f8c1c4f23b6c4cfe59fd574b59  2020-11-12T10:54:32+00:00
#
#       Dataset Origin                        Product Id  Product Barcode  \
# 0                NaN  2e17bf4acecdece67fc00f07ad62c910              NaN
# ...

# %%
data.columns
# Out:
# Index(['Uniq Id', 'Crawl Timestamp', 'Dataset Origin', 'Product Id',
#        'Product Barcode', 'Product Company Type Source',
#        'Product Brand Source', 'Product Brand Normalised Source',
#        'Product Name Source', 'Match Rank', 'Match Score', 'Match Type',
#        'Retailer', 'Product Category', 'Product Brand', 'Product Name',
#        'Product Price', 'Sku', 'Upc', 'Product Url', 'Market',
#        'Product Description', 'Product Currency',
#        'Product Available Inventory', 'Product Image Url',
#        'Product Model Number', 'Product Tags', 'Product Contents',
#        'Product Rating', 'Product Reviews Count', 'Bsr', 'Joining Key'],
#       dtype='object')

# %%
data = data[['Uniq Id','Product Id', 'Product Rating', 'Product Reviews Count', 'Product Category', 'Product Brand', 'Product Name', 'Product Image Url', 'Product Description', 'Product Tags']]

# %%
data
# Out:
#                                Uniq Id                        Product Id  \
# 0     1705736792d82aa2f2d3caf1c07c53f4  2e17bf4acecdece67fc00f07ad62c910
# 1     95a9fe6f4810fcfc7ff244fd06784f11  076e5854a62dd283c253d6bae415af1f
# 2     8d4d0330178d3ed181b15a4102b287f2  8a4fe5d9c7a6ed26cc44d785a454b124
# 3     fddc4df45b35efd886794b261f730c51  03b5fb878a33eadff8b033419eab9669
# 4     0990cf89a59ca6a0460349a3e4f51d42  ce3d761e57d6ccad80619297b5b1bcbc
# ...                                ...                               ...
# 4995  2771f0606e9638de508741f52029d51c  ad208aa8da338e84dfcf13efd49e8a75
# 4996  0f218eb3ac736975ccfdde987baa4b83  1be8241fd6249f7ee007b06afd7ff45d
# 4997  34d1aa70845416c3df059a088aaf18dc  96ed378fb9466b11abde8f9baea58844
# 4998  ff9cfa22550bf036e2487a9100d927f1  f7b05869f3ee7fe22864ea58cbb006d1
# 4999  0de862f8c1c4f23b6c4cfe59fd574b59  1c9e4943fd915f7b016cdc593e607e02
#
#       Product Rating  Product Reviews Count  \
# 0                NaN                    NaN
# ...

# %%
data.columns
# Out:
# Index(['Uniq Id', 'Product Id', 'Product Rating', 'Product Reviews Count',
#        'Product Category', 'Product Brand', 'Product Name',
#        'Product Image Url', 'Product Description', 'Product Tags'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Uniq Id                     0
# Product Id                  0
# Product Rating           2806
# Product Reviews Count    1654
# Product Category           10
# Product Brand              13
# Product Name                0
# Product Image Url           0
# Product Description      1127
# Product Tags                0
# dtype: int64

# %%
data['Product Rating'].fillna(0, inplace=True)
data['Product Reviews Count'].fillna(0,inplace=True)
data['Product Category'].fillna(0,inplace=True)
data['Product Brand'].fillna(0,inplace=True)
data['Product Description'].fillna(0,inplace=True)
# Out:
# C:\Users\sohan\AppData\Local\Temp\ipykernel_17740\4154497093.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Product Rating'].fillna(0, inplace=True)
# C:\Users\sohan\AppData\Local\Temp\ipykernel_17740\4154497093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Product Rating'].fillna(0, inplace=True)
# ...

# %%
data.isnull().sum()
# Out:
# Uniq Id                  0
# Product Id               0
# Product Rating           0
# Product Reviews Count    0
# Product Category         0
# Product Brand            0
# Product Name             0
# Product Image Url        0
# Product Description      0
# Product Tags             0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.columns
# Out:
# Index(['Uniq Id', 'Product Id', 'Product Rating', 'Product Reviews Count',
#        'Product Category', 'Product Brand', 'Product Name',
#        'Product Image Url', 'Product Description', 'Product Tags'],
#       dtype='object')

# %%
ColumnMapping = {
    'Uniq Id': 'ID',
    'Product Id':'prodID',
    'Product Rating':'Rating',
    'Product Review Count':'ReviewCount',
    'Product Category':'Category',
    'Product Brand': 'Brand',
    'Product Name': 'Name',
    'Product Image url':'ImageURL',
    'Product Description':'Description',
    'Product Tags':'Tags',
    'Product Contents':'Contents'
}
data.rename(columns=ColumnMapping, inplace=True)
# Out:
# C:\Users\sohan\AppData\Local\Temp\ipykernel_17740\3953486612.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns=ColumnMapping, inplace=True)

# %%
data
# Out:
#                                     ID                            prodID  \
# 0     1705736792d82aa2f2d3caf1c07c53f4  2e17bf4acecdece67fc00f07ad62c910
# 1     95a9fe6f4810fcfc7ff244fd06784f11  076e5854a62dd283c253d6bae415af1f
# 2     8d4d0330178d3ed181b15a4102b287f2  8a4fe5d9c7a6ed26cc44d785a454b124
# 3     fddc4df45b35efd886794b261f730c51  03b5fb878a33eadff8b033419eab9669
# 4     0990cf89a59ca6a0460349a3e4f51d42  ce3d761e57d6ccad80619297b5b1bcbc
# ...                                ...                               ...
# 4995  2771f0606e9638de508741f52029d51c  ad208aa8da338e84dfcf13efd49e8a75
# 4996  0f218eb3ac736975ccfdde987baa4b83  1be8241fd6249f7ee007b06afd7ff45d
# 4997  34d1aa70845416c3df059a088aaf18dc  96ed378fb9466b11abde8f9baea58844
# 4998  ff9cfa22550bf036e2487a9100d927f1  f7b05869f3ee7fe22864ea58cbb006d1
# 4999  0de862f8c1c4f23b6c4cfe59fd574b59  1c9e4943fd915f7b016cdc593e607e02
#
#       Rating  Product Reviews Count  \
# 0        0.0                    0.0
# ...

# %%
data['ID']
# Out:
# 0       1705736792d82aa2f2d3caf1c07c53f4
# 1       95a9fe6f4810fcfc7ff244fd06784f11
# 2       8d4d0330178d3ed181b15a4102b287f2
# 3       fddc4df45b35efd886794b261f730c51
# 4       0990cf89a59ca6a0460349a3e4f51d42
#                       ...
# 4995    2771f0606e9638de508741f52029d51c
# 4996    0f218eb3ac736975ccfdde987baa4b83
# 4997    34d1aa70845416c3df059a088aaf18dc
# 4998    ff9cfa22550bf036e2487a9100d927f1
# 4999    0de862f8c1c4f23b6c4cfe59fd574b59
# Name: ID, Length: 5000, dtype: object

# %%
data['ID'] = data['ID'].str.extract(r'(\d+)').astype(float)
# Out:
# C:\Users\sohan\AppData\Local\Temp\ipykernel_17740\769714033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ID'] = data['ID'].str.extract(r'(\d+)').astype(float)

# %%
data['ID']
# Out:
# 0       1.705737e+09
# 1       9.500000e+01
# 2       8.000000e+00
# 3       4.000000e+00
# 4       9.900000e+02
#             ...
# 4995    2.771000e+03
# 4996    0.000000e+00
# 4997    3.400000e+01
# 4998    9.000000e+00
# 4999    0.000000e+00
# Name: ID, Length: 5000, dtype: float64

# %%
data['prodID'] = data['prodID'].str.extract(r'(\d+)').astype(float)
# Out:
# C:\Users\sohan\AppData\Local\Temp\ipykernel_17740\1985494369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['prodID'] = data['prodID'].str.extract(r'(\d+)').astype(float)

# %%
data['prodID']
# Out:
# 0         2.0
# 1        76.0
# 2         8.0
# 3         3.0
# 4         3.0
#         ...
# 4995    208.0
# 4996      1.0
# 4997     96.0
# 4998      7.0
# 4999      1.0
# Name: prodID, Length: 5000, dtype: float64

# %%
# EDA

# %%
print(f'Number of unique users:', data['ID'].nunique())
print(f'Number of unique items:', data['prodID'].nunique())
print(f'Number of unique ratings:', data['Rating'].nunique())
# Out:
# Number of unique users: 1721
# Number of unique items: 1697
# Number of unique ratings: 36

# %%
heatmapdata = data.pivot_table('ID', 'Rating')
plt.figure(figsize=(8, 6))
sns.heatmap(heatmapdata, annot=True, fmt='g', cmap='coolwarm', cbar=True)
plt.title("heat-map of user Ratings")
plt.xlabel('Ratings')
plt.ylabel('User ID')
plt.show()

# %%
# want to find distribution of data , genreally how was the interaction with the products

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
data['ID'].value_counts().hist(bins=10, edgecolor='k')
plt.xlabel('Interaction per user')
plt.ylabel('Number of useres')
plt.title('Distribution of Interactions per user')

plt.subplot(1, 2, 2)
data['prodID'].value_counts().hist(bins=10, edgecolor='k', color='red')
plt.xlabel('Interactions per item')
plt.ylabel('Number of Items')
plt.title('Distribution of Interactions per item')


plt.tight_layout()
plt.show()

# %%
popularItem = data['prodID'].value_counts().head(10)
popularItem.plot(kind='bar', color='red')
plt.title("The most POPULAR ITEMS")
# Out:
# Text(0.5, 1.0, 'The most POPULAR ITEMS')

# %%
data['Rating'].value_counts().plot(kind='bar', color='red')
# Out:
# <Axes: xlabel='Rating'>

# %%
data['Tags']
# Out:
# 0       OPI Infinite Shine, Nail Lacquer Nail Polish, ...
# 1       Nice 'n Easy Permanent Color, 111 Natural Medi...
# 2       Clairol Nice 'N Easy Permanent Color 7/106A Na...
# 3       Kokie Professional Matte Lipstick, Hot Berry, ...
# 4       Gillette TRAC II Plus Razor Blade Refills, Fit...
#                               ...
# 4995    Garden Mint Room Spray (Double Strength), 4 ou...
# 4996    Garnier Nutrisse Nourishing Hair Color Creme (...
# 4997    Nail File Electric Drill, 6 in 1 Professional ...
# 4998    Creed Love In Black Hair And Body Wash 6.8oz/2...
# 4999                    Foundation, Wal-mart, Walmart.com
# Name: Tags, Length: 5000, dtype: object

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

nlp = spacy.load("en_core_web_sm")

def cleanandextracttags(text):
    if not isinstance(text, str):
        text = str(text)  
    doc = nlp(text.lower())
    tags = [token.text for token in doc if token.text.isalnum() and token.text not in STOP_WORDS]
    return ', '.join(tags)

columnstoextracttagsfrom = ['Category', 'Brand', 'Description']
for columns in columnstoextracttagsfrom:
    data[columns] = data[columns].apply(cleanandextracttags)
# Out:
# C:\Users\sohan\AppData\Local\Temp\ipykernel_17740\3318875940.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[columns] = data[columns].apply(cleanandextracttags)

# %%
data
# Out:
#                 ID  prodID  Rating  Product Reviews Count  \
# 0     1.705737e+09     2.0     0.0                    0.0
# 1     9.500000e+01    76.0     0.0                    0.0
# 2     8.000000e+00     8.0     4.5                29221.0
# 3     4.000000e+00     3.0     0.0                    0.0
# 4     9.900000e+02     3.0     0.0                  131.0
# ...            ...     ...     ...                    ...
# 4995  2.771000e+03   208.0     4.5                    2.0
# 4996  0.000000e+00     1.0     3.9                 7484.0
# 4997  3.400000e+01    96.0     0.0                    4.0
# 4998  9.000000e+00     7.0     0.0                    0.0
# 4999  0.000000e+00     1.0     0.0                  438.0
#
#                                                Category             Brand  \
# 0     premium, beauty, premium, makeup, premium, nai...               opi
# 1     beauty, hair, care, hair, color, auburn, hair,...              easy
# ...

# %%
data['Tags'] = data[columnstoextracttagsfrom].apply(lambda row: ', '.join(row), axis=1)
# Out:
# C:\Users\sohan\AppData\Local\Temp\ipykernel_17740\3076123806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Tags'] = data[columnstoextracttagsfrom].apply(lambda row: ', '.join(row), axis=1)

# %%
data['Tags']
# Out:
# 0       premium, beauty, premium, makeup, premium, nai...
# 1       beauty, hair, care, hair, color, auburn, hair,...
# 2       beauty, hair, care, hair, color, permanent, ha...
# 3       beauty, makeup, lip, kokie, cosmetics, calling...
# 4       seasonal, stock, essentials, personal, care, s...
#                               ...
# 4995    household, essentials, air, fresheners, spray,...
# 4996    beauty, hair, care, hair, color, permanent, ha...
# 4997    beauty, makeup, nails, stoneway, multifunction...
# 4998    premium, beauty, premium, bath, body, premium,...
# 4999    beauty, makeup, face, makeup, face, makeup, br...
# Name: Tags, Length: 5000, dtype: object

# %%
# rating based Recommendation system

# %%
data
# Out:
#                 ID  prodID  Rating  Product Reviews Count  \
# 0     1.705737e+09     2.0     0.0                    0.0
# 1     9.500000e+01    76.0     0.0                    0.0
# 2     8.000000e+00     8.0     4.5                29221.0
# 3     4.000000e+00     3.0     0.0                    0.0
# 4     9.900000e+02     3.0     0.0                  131.0
# ...            ...     ...     ...                    ...
# 4995  2.771000e+03   208.0     4.5                    2.0
# 4996  0.000000e+00     1.0     3.9                 7484.0
# 4997  3.400000e+01    96.0     0.0                    4.0
# 4998  9.000000e+00     7.0     0.0                    0.0
# 4999  0.000000e+00     1.0     0.0                  438.0
#
#                                                Category             Brand  \
# 0     premium, beauty, premium, makeup, premium, nai...               opi
# 1     beauty, hair, care, hair, color, auburn, hair,...              easy
# ...

# %%
avgratings = data.groupby(['Name', 'Product Reviews Count', 'Brand', 'Product Image Url'])['Rating'].mean().reset_index()

# %%
avgratings
# Out:
#                                                    Name  \
# 0     $6 Mail-In Rebate Available Braun Epilator Sil...
# 1     ($100 Value) Peter Thomas Roth Thermal Therapy...
# 2     ($11 Value) Love Beauty and Planet Coconut Wat...
# 3     ($125 Value) Impressions Vanity Touch Pro LED ...
# 4     ($129 Value) CHI G2 Ceramic Titanium Infused H...
# ...                                                 ...
# 4987  wet n wild Photo Focus Correcting Palette, Col...
# 4988  wet n wild Photo Focus Liquid Foundation, Medi...
# 4989   wet n wild Photo Focus Pressed Powder, Dark Café
# 4990  wet n wild Silk Finish Lipstick, Honolulu Is C...
# 4991                     wnw i-shimmer eyepencil sky li
#
#       Product Reviews Count                 Brand  \
# 0                     146.0                 braun
# 1                       1.0   peter, thomas, roth
# 2                     278.0  love, beauty, planet
# 3                       2.0   impressions, vanity
# ...

# %%
toprateditems = avgratings.sort_values(by='Rating', ascending=False)

# %%
toprateditems
# Out:
#                                                    Name  \
# 1686  Electric Shaver, Triple Shaving Time Electric ...
# 526                 Alaffia Body Lotion, Vanilla, 32 Oz
# 2053  Gold Bond Ultimate Ultimate Healing Lotion, Al...
# 4716  Versace Man Eau Fraiche Eau De Toilette Spray,...
# 2058  Goldwell StyleSign 1 Flat Marvel Straightening...
# ...                                                 ...
# 2172  Herbal Clean Same-Day Premium Detox Drink 20oz...
# 2173  Herbal Clean Same-Day Premium Detox Drink, 32o...
# 2174  Herbal Essences Bio:renew Vitamin E with Cocoa...
# 2175  Herbal Essences Color Me Happy Conditioner Aca...
# 4991                     wnw i-shimmer eyepencil sky li
#
#       Product Reviews Count             Brand  \
# 1686                    4.0            moosoo
# 526                     2.0           alaffia
# 2053                    2.0        gold, bond
# 4716                   24.0           versace
# 2058                    2.0          goldwell
# ...

# %%
ratingbaserecommendation = toprateditems.head(10)

# %%
ratingbaserecommendation
# Out:
#                                                    Name  \
# 1686  Electric Shaver, Triple Shaving Time Electric ...
# 526                 Alaffia Body Lotion, Vanilla, 32 Oz
# 2053  Gold Bond Ultimate Ultimate Healing Lotion, Al...
# 4716  Versace Man Eau Fraiche Eau De Toilette Spray,...
# 2058  Goldwell StyleSign 1 Flat Marvel Straightening...
# 3842  Red Devil 0322 Steel Wool # 00 Very Fine, 8 Pa...
# 510   Air Wick Plug in Starter Kit, Warmer + 1 Refil...
# 3841  Recovery Complex Anti-Frizz Shine Serum by Bai...
# 2687  Long Aid Extra Dry Formula Curl Activator Gel ...
# 2062  Good Sense 60-Day Air Care System, Citrus, 2 o...
#
#       Product Reviews Count            Brand  \
# 1686                    4.0           moosoo
# 526                     2.0          alaffia
# 2053                    2.0       gold, bond
# 4716                   24.0          versace
# 2058                    2.0         goldwell
# 3842                    1.0       red, devil
# ...

# %%
ratingbaserecommendation['Rating'] = ratingbaserecommendation['Rating'].astype(int)
ratingbaserecommendation['Product Reviews Count'] = ratingbaserecommendation['Product Reviews Count'].astype(int)
# Out:
# C:\Users\sohan\AppData\Local\Temp\ipykernel_17740\3078775327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratingbaserecommendation['Rating'] = ratingbaserecommendation['Rating'].astype(int)
# C:\Users\sohan\AppData\Local\Temp\ipykernel_17740\3078775327.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratingbaserecommendation['Product Reviews Count'] = ratingbaserecommendation['Product Reviews Count'].astype(int)

# %%
ratingbaserecommendation
# Out:
#                                                    Name  \
# 1686  Electric Shaver, Triple Shaving Time Electric ...
# 526                 Alaffia Body Lotion, Vanilla, 32 Oz
# 2053  Gold Bond Ultimate Ultimate Healing Lotion, Al...
# 4716  Versace Man Eau Fraiche Eau De Toilette Spray,...
# 2058  Goldwell StyleSign 1 Flat Marvel Straightening...
# 3842  Red Devil 0322 Steel Wool # 00 Very Fine, 8 Pa...
# 510   Air Wick Plug in Starter Kit, Warmer + 1 Refil...
# 3841  Recovery Complex Anti-Frizz Shine Serum by Bai...
# 2687  Long Aid Extra Dry Formula Curl Activator Gel ...
# 2062  Good Sense 60-Day Air Care System, Citrus, 2 o...
#
#       Product Reviews Count            Brand  \
# 1686                      4           moosoo
# 526                       2          alaffia
# 2053                      2       gold, bond
# 4716                     24          versace
# 2058                      2         goldwell
# 3842                      1       red, devil
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data.head(2)
# Out:
#              ID  prodID  Rating  Product Reviews Count  \
# 0  1.705737e+09     2.0     0.0                    0.0
# 1  9.500000e+01    76.0     0.0                    0.0
#
#                                             Category Brand  \
# 0  premium, beauty, premium, makeup, premium, nai...   opi
# 1  beauty, hair, care, hair, color, auburn, hair,...  easy
#
#                                                 Name  \
# 0  OPI Infinite Shine, Nail Lacquer Nail Polish, ...
# 1  Nice n Easy Permanent Color, 111 Natural Mediu...
#
#                                    Product Image Url  \
# 0  https://i5.walmartimages.com/asr/0e1f4c51-c1a4...
# 1  https://i5.walmartimages.com/asr/9c8e42e4-13a5...
#
#                                          Description  \
# 0                                                  0
# 1  pack, 3, pack, 3, upc, 381519000201, beautiful...
#
#                                                 Tags
# 0  premium, beauty, premium, makeup, premium, nai...
# ...

# %%
tfidfvectorizer = TfidfVectorizer(stop_words='english')
tfidfmatrixcontent = tfidfvectorizer.fit_transform(data['Tags'])

# %%
cosinesimilaritycontent = cosine_similarity(tfidfmatrixcontent, tfidfmatrixcontent)

# %%
cosinesimilaritycontent
# Out:
# array([[1.        , 0.00347577, 0.00363226, ..., 0.13535785, 0.31726435,
#         0.05689108],
#        [0.00347577, 1.        , 0.38086046, ..., 0.02315363, 0.00183907,
#         0.0381051 ],
#        [0.00363226, 0.38086046, 1.        , ..., 0.03960089, 0.00192187,
#         0.0591094 ],
#        ...,
#        [0.13535785, 0.02315363, 0.03960089, ..., 1.        , 0.00123005,
#         0.0379399 ],
#        [0.31726435, 0.00183907, 0.00192187, ..., 0.00123005, 1.        ,
#         0.00544407],
#        [0.05689108, 0.0381051 , 0.0591094 , ..., 0.0379399 , 0.00544407,
#         1.        ]])

# %%
data['Name'][0]
# Out:
# 'OPI Infinite Shine, Nail Lacquer Nail Polish, Bubble Bath'

# %%
itemname = 'OPI Infinite Shine, Nail Lacquer Nail Polish, Bubble Bath'
itemindex = data[data['Name']==itemname].index[0]

# %%
similaritems = list(enumerate(cosinesimilaritycontent[itemindex]))

# %%
similaritems
# Out:
# [(0, 1.0),
#  (1, 0.0034757732312750934),
#  (2, 0.003632261383918426),
#  (3, 0.013151377769582695),
#  (4, 0.0010160210269512565),
#  (5, 0.006575809352364544),
#  (6, 0.007328463323503305),
#  (7, 0.05151153351231972),
#  (8, 0.011109860476686882),
#  (9, 0.003151730172379002),
#  (10, 0.0),
#  (11, 0.1587457628497677),
#  (12, 0.04098008361044332),
#  (13, 0.0030468898686792107),
#  (14, 0.0),
#  (15, 0.0059693458494800575),
#  (16, 0.3398806576145607),
#  (17, 0.0),
#  (18, 0.004556103655641239),
#  (19, 0.0038887588090144405),
#  (20, 0.008764149884645193),
#  (21, 0.0),
#  (22, 0.009458897953602717),
#  (23, 0.0),
#  (24, 0.00517558550504985),
#  (25, 0.0),
#  (26, 0.007172857177991527),
#  (27, 0.003259884833851906),
#  (28, 0.2812052802661157),
#  (29, 0.0),
#  (30, 0.007207084216281134),
#  (31, 0.006229511383962109),
#  (32, 0.008773214115073319),
#  (33, 0.010764957375515107),
#  (34, 0.005638510010303099),
#  (35, 0.01026020396150954),
#  (36, 0.0020164119152476824),
# ...

# %%
similaritems = sorted(similaritems, key=lambda x:x[1], reverse=True)

# %%
similaritems
# Out:
# [(0, 1.0),
#  (156, 1.0),
#  (184, 1.0),
#  (205, 1.0),
#  (237, 1.0),
#  (325, 1.0),
#  (375, 1.0),
#  (402, 1.0),
#  (706, 1.0),
#  (886, 1.0),
#  (1042, 1.0),
#  (1108, 1.0),
#  (1215, 1.0),
#  (1257, 1.0),
#  (1280, 1.0),
#  (1346, 1.0),
#  (1442, 1.0),
#  (1575, 1.0),
#  (1594, 1.0),
#  (1633, 1.0),
#  (1654, 1.0),
#  (1687, 1.0),
#  (1743, 1.0),
#  (1747, 1.0),
#  (1853, 1.0),
#  (1883, 1.0),
#  (1895, 1.0),
#  (1896, 1.0),
#  (1984, 1.0),
#  (1991, 1.0),
#  (2027, 1.0),
#  (2101, 1.0),
#  (2159, 1.0),
#  (2355, 1.0),
#  (2418, 1.0),
#  (2484, 1.0),
#  (2485, 1.0),
#  (2510, 1.0),
#  (2511, 1.0),
#  (2514, 1.0),
#  (2548, 1.0),
#  (2564, 1.0),
#  (2576, 1.0),
#  (2710, 1.0),
#  (2748, 1.0),
#  (2904, 1.0),
#  (2952, 1.0),
#  (2977, 1.0),
#  (3015, 1.0),
#  (3052, 1.0),
#  (3199, 1.0),
#  (3202, 1.0),
#  (3211, 1.0),
#  (3236, 1.0),
#  (3252, 1.0),
#  (3253, 1.0),
#  (3299, 1.0),
#  (3366, 1.0),
#  (3460, 1.0),
#  (3639, 1.0),
#  (3691, 1.0),
#  (3692, 1.0),
#  (3719, 1.0),
# ...

# %%
topsimilaritems = similaritems[1:10]

# %%
topsimilaritems
# Out:
# [(156, 1.0),
#  (184, 1.0),
#  (205, 1.0),
#  (237, 1.0),
#  (325, 1.0),
#  (375, 1.0),
#  (402, 1.0),
#  (706, 1.0),
#  (886, 1.0)]

# %%
recommendeditemsindices = [x[0] for x in topsimilaritems]

# %%
recommendeditemsindices
# Out:
# [156, 184, 205, 237, 325, 375, 402, 706, 886]

# %%
data.iloc[recommendeditemsindices][['Name', 'Product Reviews Count', 'Brand']]
# Out:
#                                                   Name  Product Reviews Count  \
# 156  OPI Nail Lacquer Polish .5oz/15mL - This Gown ...                    0.0
# 184  OPI Nail Gel Polish GelColor .5oz/15mL 3 CT Co...                    0.0
# 205  OPI Nail Lacquer - Dont Bossa Nova Me Around -...                    0.0
# 237  OPI Infinite Shine 2 Polish - ISL P33 - Alpaca...                    5.0
# 325  OPI Gel Polish Fall 2019 Scotland Collection G...                    1.0
# 375  OPI Nail Gel Polish GelColor .5oz/15mL 3 CT Co...                    1.0
# 402   OPI Nail Polish, Strawberry Margarita, 0.5 Fl Oz                   57.0
# 706  OPI Nail Gel Polish GelColor .5oz/15mL 3 CT Co...                    1.0
# 886  OPI- Nail Lacquer-GelColor - &quotLiv&quotin t...                    0.0
#
#     Brand
# 156   opi
# 184   opi
# 205   opi
# 237   opi
# 325   opi
# 375   opi
# 402   opi
# 706   opi
# 886   opi

# %%
#combine function code
def contentbasedrecommendation(data, itemname, n=20):
    if itemname not in data['Name'].values:
        print(f"item '{itemname}' not found in the training data.")
        return pd.DataFrame()
    
    tfidfvectorizer = TfidfVectorizer(stop_words='english')
    cosinesimilaritycontent = cosine_similarity(tfidfmatrixcontent, tfidfmatrixcontent)
    itemindex = data[data['Name'] == itemname].index[0]
    similaritems = list(enumerate(cosinesimilaritycontent[itemindex]))
    similaritems = sorted(similaritems, key=lambda x: x[1], reverse=True)
    topsimilaritems = similaritems[1:n+1]
    recommendeditemindices = [x[0] for x in topsimilaritems]
    recommendeditemdetails = data.iloc[recommendeditemindices][['Name', 'Product Reviews Count', 'Brand', 'Product Image Url', 'Rating']]
    return recommendeditemdetails

# %%
itemname = 'OPI Infinite Shine, Nail Lacquer Nail Polish, Bubble Bath'
contentbasedrec = contentbasedrecommendation(data, itemname, n=10)
contentbasedrec
# Out:
#                                                    Name  \
# 156   OPI Nail Lacquer Polish .5oz/15mL - This Gown ...
# 184   OPI Nail Gel Polish GelColor .5oz/15mL 3 CT Co...
# 205   OPI Nail Lacquer - Dont Bossa Nova Me Around -...
# 237   OPI Infinite Shine 2 Polish - ISL P33 - Alpaca...
# 325   OPI Gel Polish Fall 2019 Scotland Collection G...
# 375   OPI Nail Gel Polish GelColor .5oz/15mL 3 CT Co...
# 402    OPI Nail Polish, Strawberry Margarita, 0.5 Fl Oz
# 706   OPI Nail Gel Polish GelColor .5oz/15mL 3 CT Co...
# 886   OPI- Nail Lacquer-GelColor - &quotLiv&quotin t...
# 1042  OPI GelColor Gel Nail Polish, Dulce De Leche, ...
#
#       Product Reviews Count Brand  \
# 156                     0.0   opi
# 184                     0.0   opi
# 205                     0.0   opi
# 237                     5.0   opi
# 325                     1.0   opi
# 375                     1.0   opi
# 402                    57.0   opi
# 706                     1.0   opi
# ...

# %%
# collaborative filtering(user item similarity)
data
# Out:
#                 ID  prodID  Rating  Product Reviews Count  \
# 0     1.705737e+09     2.0     0.0                    0.0
# 1     9.500000e+01    76.0     0.0                    0.0
# 2     8.000000e+00     8.0     4.5                29221.0
# 3     4.000000e+00     3.0     0.0                    0.0
# 4     9.900000e+02     3.0     0.0                  131.0
# ...            ...     ...     ...                    ...
# 4995  2.771000e+03   208.0     4.5                    2.0
# 4996  0.000000e+00     1.0     3.9                 7484.0
# 4997  3.400000e+01    96.0     0.0                    4.0
# 4998  9.000000e+00     7.0     0.0                    0.0
# 4999  0.000000e+00     1.0     0.0                  438.0
#
#                                                Category             Brand  \
# 0     premium, beauty, premium, makeup, premium, nai...               opi
# 1     beauty, hair, care, hair, color, auburn, hair,...              easy
# ...

# %%
useritemmatrix = data.pivot_table(index='ID', columns='prodID', values='Rating', aggfunc = 'mean').fillna(0).astype(int)

# %%
useritemmatrix
# Out:
# prodID        0.000000e+00  1.000000e+00  2.000000e+00  3.000000e+00  \
# ID
# 0.000000e+00             2             1             2             1
# 1.000000e+00             1             0             2             2
# 2.000000e+00             1             1             3             1
# 3.000000e+00             1             1             1             2
# 4.000000e+00             3             0             2             1
# ...                    ...           ...           ...           ...
# 9.967409e+13             0             0             0             0
# 6.094514e+14             0             0             0             0
# 3.007694e+17             0             0             0             0
# 3.081297e+19             0             0             0             0
# 8.148290e+23             0             0             0             0
#
# prodID        4.000000e+00  5.000000e+00  6.000000e+00  7.000000e+00  \
# ID
# ...

# %%
usersimilarity = cosine_similarity(useritemmatrix)

# %%
usersimilarity
# Out:
# array([[1.        , 0.08328508, 0.08776176, ..., 0.        , 0.03388371,
#         0.        ],
#        [0.08328508, 1.        , 0.09334828, ..., 0.        , 0.        ,
#         0.        ],
#        [0.08776176, 0.09334828, 1.        , ..., 0.        , 0.0417756 ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.03388371, 0.        , 0.0417756 , ..., 0.        , 1.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
targetuserid = 10
targetuserindex = useritemmatrix.index.get_loc(targetuserid)

# %%
targetuserindex
# Out:
# 10

# %%
usersimilarities = usersimilarity[targetuserindex]
usersimilarities
# Out:
# array([0.06256194, 0.082515  , 0.09255997, ..., 0.        , 0.36927447,
#        0.        ])

# %%
similaruserindices = usersimilarities.argsort()[::-1][1:]

# %%
similaruserindices
# Out:
# array([  28,   96,   97, ..., 1133, 1134,  860], dtype=int64)

# %%
recommendeditems = []
for userindex in similaruserindices:
    ratedbysimilaruser = useritemmatrix.iloc[userindex]
    notratedbytargetuser = (ratedbysimilaruser == 0) & (useritemmatrix.iloc[targetuserindex] == 0)
    
    recommendeditems.extend(useritemmatrix.columns[notratedbytargetuser][:10])
    
recommendeditemsdetail = data[data['prodID'].isin(recommendeditems)][['Name', 'Product Reviews Count', 'Brand', 'Product Image Url', 'Rating']].head(10)

# %%
recommendeditemsdetail
# Out:
#                                                  Name  Product Reviews Count  \
# 0   OPI Infinite Shine, Nail Lacquer Nail Polish, ...                    0.0
# 3   Kokie Professional Matte Lipstick, Hot Berry, ...                    0.0
# 4   Gillette TRAC II Plus Razor Blade Refills, Fit...                  131.0
# 15  Clairol Natural Instincts Demi-Permanent Hair ...                 2935.0
# 24  Hempz Milk & Honey Herbal Body Moisturizer 2.2...                    7.0
# 27  9 Types Women Reusable Washable Panty Liner Ba...                    0.0
# 30  2 Pack - AVEENO Active Naturals Intense Relief...                   50.0
# 33  DenTek Kids Fun Flossers, Removes Food & Plaqu...                    3.0
# 44  (4 pack) Crest Pro-Health Sensitive & Enamel S...                   86.0
# 61  COVERGIRL Exhibitionist Cream Lipstick, 395 Da...                  713.0
#
#                Brand                                  Product Image Url  \
# ...

# %%
def collaborativefilteringrecommendation(data, targetuserid, n):
    useritemmatrix = data.pivot_table(index='ID', columns='prodID', values='Rating', aggfunc='mean').fillna(0)
    usersimilarity = cosine_similarity(useritemmatrix)
    targetuserindex = useritemmatrix.index.get_loc(targetuserid)
    usersimilarities = usersimilarity[targetuserindex]
    similaruserindices = usersimilarities.argsort()[::-1][1:]
    
    recommendeditems = []
    for userindex in similaruserindices:
        ratedbysimilaruser = useritemmatrix.iloc[userindex]
        notratedbytargetuser = (ratedbysimilaruser == 0) & (useritemmatrix.iloc[targetuserindex] == 0)
        recommendeditems.extend(useritemmatrix.columns[notratedbytargetuser][:n])
    recommendeditemsdetail = data[data['prodID'].isin(recommendeditems)][['Name', 'Product Reviews Count', 'Brand', 'Product Image Url', 'Rating']]
    return recommendeditemsdetails

targetuserid = 4
n = 20
collaborative_filtering_rec = collaborativefilteringrecommendation(data, targetuserid, n)
print(f"top {n} recommendations for user {targetuserid}:")
collaborative_filtering_rec.head(n)
# Out:
# top 20 recommendations for user 4:
#                                                  Name  Product Reviews Count  \
# 0   OPI Infinite Shine, Nail Lacquer Nail Polish, ...                    0.0
# 3   Kokie Professional Matte Lipstick, Hot Berry, ...                    0.0
# 4   Gillette TRAC II Plus Razor Blade Refills, Fit...                  131.0
# 15  Clairol Natural Instincts Demi-Permanent Hair ...                 2935.0
# 24  Hempz Milk & Honey Herbal Body Moisturizer 2.2...                    7.0
# 27  9 Types Women Reusable Washable Panty Liner Ba...                    0.0
# 30  2 Pack - AVEENO Active Naturals Intense Relief...                   50.0
# 33  DenTek Kids Fun Flossers, Removes Food & Plaqu...                    3.0
# 44  (4 pack) Crest Pro-Health Sensitive & Enamel S...                   86.0
# 61  COVERGIRL Exhibitionist Cream Lipstick, 395 Da...                  713.0
# 64  Neutrogena SkinClearing Oil-Free Liquid Founda...                  741.0
# ...

# %%
# uses simple technique just for idea
def hybridrecommendation(data, targetuserid, itemname, n = 10):
    contentbasedrec = contentbasedrecommendation(data, itemname, n)
    collaborativefilteringrec = collaborativefilteringrecommendation(data, targetuserid, n)
    hybridrec = pd.concat([contentbasedrec, collaborativefilteringrec]).drop_duplicates()
    
    return hybridrec.head(10)

# %%
targetuserid = 4
itemname = 'OPI Infinite Shine, Nail Lacquer Nail Polish, Bubble Bath'
hybridrec = hybridrecommendation(data, targetuserid, itemname, n=10)
print(f"top 10 Hybrid Recommendation for user{targetuserid} and item '{itemname}':")
hybridrec
# Out:
# top 10 Hybrid Recommendation for user4 and item 'OPI Infinite Shine, Nail Lacquer Nail Polish, Bubble Bath':
#                                                    Name  \
# 156   OPI Nail Lacquer Polish .5oz/15mL - This Gown ...
# 184   OPI Nail Gel Polish GelColor .5oz/15mL 3 CT Co...
# 205   OPI Nail Lacquer - Dont Bossa Nova Me Around -...
# 237   OPI Infinite Shine 2 Polish - ISL P33 - Alpaca...
# 325   OPI Gel Polish Fall 2019 Scotland Collection G...
# 375   OPI Nail Gel Polish GelColor .5oz/15mL 3 CT Co...
# 402    OPI Nail Polish, Strawberry Margarita, 0.5 Fl Oz
# 706   OPI Nail Gel Polish GelColor .5oz/15mL 3 CT Co...
# 886   OPI- Nail Lacquer-GelColor - &quotLiv&quotin t...
# 1042  OPI GelColor Gel Nail Polish, Dulce De Leche, ...
#
#       Product Reviews Count Brand  \
# 156                     0.0   opi
# 184                     0.0   opi
# 205                     0.0   opi
# 237                     5.0   opi
# 325                     1.0   opi
# ...

# %%
targetuserid = 10
itemname = 'Black Radiance Perfect Tone Matte Lip Crème, Succulent Plum'
hybridrec = hybridrecommendation(data, targetuserid, itemname, n=10)
print(f"top 10 Hybrid Recommendation for user{targetuserid} and item '{itemname}':")
hybridrec
# Out:
# top 10 Hybrid Recommendation for user10 and item 'Black Radiance Perfect Tone Matte Lip Crème, Succulent Plum':
#                                                    Name  \
# 896   Black Radiance Perfect Tone Lip Color, Vintage...
# 2496  Black Radiance Perfect Tone Lip Color, Hollywo...
# 3     Kokie Professional Matte Lipstick, Hot Berry, ...
# 3406  Kokie Professional Matte Lipstick, Firecracker...
# 2406           L.A. Colors Matte Lipstick, Tender Matte
# 4050  Kokie Professional Lip Poudre Liquid Matte Liq...
# 2873  Kokie Professional Lip Poudre Liquid Matte Liq...
# 4872           L.A. Colors Matte Lipstick, Torrid Matte
# 1300             e.l.f. Liquid Matte Lipstick, Tea Rose
# 420   Black Opal Color Splurge Sassy Luxe Matte Lips...
#
#       Product Reviews Count             Brand  \
# 896                    78.0   black, radiance
# 2496                   18.0   black, radiance
# 3                       0.0  kokie, cosmetics
# 3406                    0.0  kokie, cosmetics
# ...
